# %%
TRAIN_CSV_PATH = '../C1-P1_Train Dev_fixed/train.csv'
VALID_CSV_PATH = '../C1-P1_Train Dev_fixed/dev.csv'
TEST_CSV_PATH = '../AIMango_sample/label.csv'

ORIGINAL_TRAIN_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Train/' 
ORIGINAL_VALID_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Dev/' 
ORIGINAL_TEST_DATA_PATH = '../AIMango_sample/sample_image/' 

TRAIN_DATA_PATH = '../data/train'
VALID_DATA_PATH = '../data/valid'
TEST_DATA_PATH = '../data/test'

# %%
import csv
import os
new_data = []
with open(TEST_CSV_PATH) as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        new_label = row[1][len(row[1])-1]
        new_data.append([row[0],new_label])


folder, filename = os.path.split(TEST_CSV_PATH)
NEW_TEST_CSV_PATH = os.path.join(folder, 'label_new.csv')
                                 
with open(NEW_TEST_CSV_PATH, 'w') as f:

    writer = csv.writer(f)
    
    for row in new_data:
        writer.writerow(row)

# %%
import csv
import os
from shutil import copyfile


# make file structure for training dataset
#
with open(TRAIN_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TRAIN_DATA_PATH, row[0])
        dest_path = os.path.join(TRAIN_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1
        
# make file structure for validation dataset
#
with open(VALID_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_VALID_DATA_PATH, row[0])
        dest_path = os.path.join(VALID_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# make file structure for validation dataset
#
with open(NEW_TEST_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TEST_DATA_PATH, row[0])
        dest_path = os.path.join(TEST_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# %%
import torch

from torchvision import datasets

import torchvision.transforms as transforms

from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# how many data per batch to load

batch_size = 32

start_epoch = 0
# Hyperparameters
lr = 0.001
valid_loss_stable_count = 10

transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.RandomHorizontalFlip(p=0.5),
                                transforms.RandomRotation(degrees=(-15, 15)),
                                transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
                                transforms.ToTensor(),
                                transforms.Normalize(
                                    mean=(0.485, 0.456, 0.406),
                                    std =(0.229, 0.224, 0.225))
                               ])
loaders_transfer = {}
data_transfer = {}

data_transfer['train'] = datasets.ImageFolder(TRAIN_DATA_PATH, transform=transform)
loaders_transfer['train'] = torch.utils.data.DataLoader(data_transfer['train'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

data_transfer['valid'] = datasets.ImageFolder(VALID_DATA_PATH, transform=transform)
loaders_transfer['valid'] = torch.utils.data.DataLoader(data_transfer['valid'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)
data_transfer['test'] = datasets.ImageFolder(TEST_DATA_PATH, transform=transform)
loaders_transfer['test'] = torch.utils.data.DataLoader(data_transfer['test'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
import torchvision.models as models
import torch.nn as nn

model_transfer = models.resnet152(pretrained=True).to(device)
    
for param in model_transfer.parameters():
    param.requires_grad = False   
    
model_transfer.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 3)).to(device)

# %%
import torch.optim as optim

criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = [optim.SGD(model_transfer.fc.parameters(), lr = lr, momentum = 0.9),
                      optim.SGD(model_transfer.fc.parameters(), lr = lr * 0.1, momentum = 0.9)]

# %%
import numpy as np
import time
import copy


# train the model
def train(n_epochs, loaders, model, optimizers, criterion, save_path):

    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    # Valid Loss Stable counter
    valid_loss_stable_counter = 0
    #optimizer index
    optim_idx = 0
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        optimizer = optimizers[optim_idx]
        
        start = time.time()
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders_transfer['train']):
            data, target = data.to(device), target.to(device)
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update accumulated training loss
            train_loss += loss.item()*data.size(0)
#             train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        valid_corrects = 0
        for batch_idx, (data, target) in enumerate(loaders_transfer['valid']):

            data, target = data.to(device), target.to(device)
            
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            _, preds = torch.max(output, 1)
            
            # calculate the batch loss
            loss = criterion(output, target)
            # update accumulated validation loss 
            valid_loss += loss.item()*data.size(0)
#             valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
    
            valid_corrects += torch.sum(preds == target.data)
        
        train_loss = train_loss/len(loaders_transfer['train'].dataset)
        valid_loss = valid_loss/len(loaders_transfer['valid'].dataset)
        
        epoch_acc = valid_corrects.double() / len(loaders_transfer['valid'].dataset)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tValidation Accuracy: {:.2f} \ttime: {:.1f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            epoch_acc,
            time.time() - start
            ))
        
        if valid_loss < valid_loss_min:
            print('Validation loss decreased from {:.6f} to {:.6f}. Model was saved'.format(
                valid_loss_min,
                valid_loss
            ))

            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(best_model_wts, save_path)


            valid_loss_min = valid_loss
            
            valid_loss_stable_counter = 0
        else:
            valid_loss_stable_counter += 1
            if valid_loss_stable_counter >= valid_loss_stable_count:
                print("use lr only one tenth of the original one to the last epoch")
                if optim_idx == 0:
                    optim_idx = 1 # optimizer with lr = lr * 0.1
                    
                    valid_loss_stable_counter = 0
                else:
                    print("early stop. return")
                    return model
    
    # return trained model
    return model

model_transfer = train(100,
                       loaders_transfer,
                       model_transfer,
                       optimizer_transfer,
                       criterion_transfer,
                       'model_transfer_v32.pt')
# Out:
# Epoch: 1 	Training Loss: 0.982657 	Validation Loss: 0.832616 	Validation Accuracy: 0.67 	time: 309.1
# Validation loss decreased from inf to 0.832616. Model was saved
# Epoch: 2 	Training Loss: 0.771104 	Validation Loss: 0.711273 	Validation Accuracy: 0.70 	time: 266.0
# Validation loss decreased from 0.832616 to 0.711273. Model was saved
# Epoch: 3 	Training Loss: 0.707738 	Validation Loss: 0.683017 	Validation Accuracy: 0.69 	time: 279.9
# Validation loss decreased from 0.711273 to 0.683017. Model was saved
# Epoch: 4 	Training Loss: 0.680891 	Validation Loss: 0.693192 	Validation Accuracy: 0.68 	time: 279.5
# Epoch: 5 	Training Loss: 0.682862 	Validation Loss: 0.638606 	Validation Accuracy: 0.71 	time: 285.7
# Validation loss decreased from 0.683017 to 0.638606. Model was saved
# Epoch: 6 	Training Loss: 0.660100 	Validation Loss: 0.675092 	Validation Accuracy: 0.68 	time: 284.2
# Epoch: 7 	Training Loss: 0.665101 	Validation Loss: 0.633372 	Validation Accuracy: 0.72 	time: 284.1
# Validation loss decreased from 0.638606 to 0.633372. Model was saved
# Epoch: 8 	Training Loss: 0.652088 	Validation Loss: 0.629404 	Validation Accuracy: 0.73 	time: 283.6
# Validation loss decreased from 0.633372 to 0.629404. Model was saved
# Epoch: 9 	Training Loss: 0.630517 	Validation Loss: 0.656522 	Validation Accuracy: 0.70 	time: 289.6
# Epoch: 10 	Training Loss: 0.643140 	Validation Loss: 0.620937 	Validation Accuracy: 0.72 	time: 289.9
# Validation loss decreased from 0.629404 to 0.620937. Model was saved
# Epoch: 11 	Training Loss: 0.658390 	Validation Loss: 0.647070 	Validation Accuracy: 0.71 	time: 284.9
# Epoch: 12 	Training Loss: 0.631494 	Validation Loss: 0.616388 	Validation Accuracy: 0.73 	time: 276.7
# Validation loss decreased from 0.620937 to 0.616388. Model was saved
# Epoch: 13 	Training Loss: 0.636257 	Validation Loss: 0.607213 	Validation Accuracy: 0.75 	time: 262.2
# Validation loss decreased from 0.616388 to 0.607213. Model was saved
# Epoch: 14 	Training Loss: 0.639819 	Validation Loss: 0.629372 	Validation Accuracy: 0.71 	time: 263.4
# Epoch: 15 	Training Loss: 0.634080 	Validation Loss: 0.640334 	Validation Accuracy: 0.72 	time: 283.2
# Epoch: 16 	Training Loss: 0.625265 	Validation Loss: 0.625095 	Validation Accuracy: 0.71 	time: 280.2
# Epoch: 17 	Training Loss: 0.626826 	Validation Loss: 0.625506 	Validation Accuracy: 0.73 	time: 281.1
# Epoch: 18 	Training Loss: 0.625292 	Validation Loss: 0.598530 	Validation Accuracy: 0.73 	time: 279.6
# Validation loss decreased from 0.607213 to 0.598530. Model was saved
# Epoch: 19 	Training Loss: 0.627438 	Validation Loss: 0.615351 	Validation Accuracy: 0.73 	time: 293.0
# Epoch: 20 	Training Loss: 0.622799 	Validation Loss: 0.607927 	Validation Accuracy: 0.71 	time: 297.3
# Epoch: 21 	Training Loss: 0.616996 	Validation Loss: 0.608263 	Validation Accuracy: 0.73 	time: 295.6
# Epoch: 22 	Training Loss: 0.610701 	Validation Loss: 0.600241 	Validation Accuracy: 0.74 	time: 281.6
# Epoch: 23 	Training Loss: 0.623549 	Validation Loss: 0.641697 	Validation Accuracy: 0.70 	time: 284.6
# Epoch: 24 	Training Loss: 0.612178 	Validation Loss: 0.586420 	Validation Accuracy: 0.74 	time: 315.4
# Validation loss decreased from 0.598530 to 0.586420. Model was saved
# Epoch: 25 	Training Loss: 0.607691 	Validation Loss: 0.628854 	Validation Accuracy: 0.72 	time: 286.0
# Epoch: 26 	Training Loss: 0.605930 	Validation Loss: 0.646933 	Validation Accuracy: 0.70 	time: 291.8
# Epoch: 27 	Training Loss: 0.610755 	Validation Loss: 0.621827 	Validation Accuracy: 0.73 	time: 289.5
# Epoch: 28 	Training Loss: 0.608740 	Validation Loss: 0.611268 	Validation Accuracy: 0.72 	time: 287.9
# Epoch: 29 	Training Loss: 0.603362 	Validation Loss: 0.649493 	Validation Accuracy: 0.71 	time: 288.0
# Epoch: 30 	Training Loss: 0.598824 	Validation Loss: 0.650771 	Validation Accuracy: 0.72 	time: 292.7
# Epoch: 31 	Training Loss: 0.613421 	Validation Loss: 0.591470 	Validation Accuracy: 0.74 	time: 297.8
# Epoch: 32 	Training Loss: 0.588792 	Validation Loss: 0.596447 	Validation Accuracy: 0.73 	time: 292.6
# Epoch: 33 	Training Loss: 0.597191 	Validation Loss: 0.619225 	Validation Accuracy: 0.72 	time: 290.2
# Epoch: 34 	Training Loss: 0.606088 	Validation Loss: 0.660340 	Validation Accuracy: 0.71 	time: 299.2
# use lr only one tenth of the original one to the last epoch
# Epoch: 35 	Training Loss: 0.582096 	Validation Loss: 0.592543 	Validation Accuracy: 0.74 	time: 290.3
# Epoch: 36 	Training Loss: 0.587950 	Validation Loss: 0.601409 	Validation Accuracy: 0.74 	time: 290.8
# Epoch: 37 	Training Loss: 0.578977 	Validation Loss: 0.587873 	Validation Accuracy: 0.73 	time: 293.9
# Epoch: 38 	Training Loss: 0.577966 	Validation Loss: 0.573319 	Validation Accuracy: 0.75 	time: 294.9
# Validation loss decreased from 0.586420 to 0.573319. Model was saved
# Epoch: 39 	Training Loss: 0.574810 	Validation Loss: 0.581266 	Validation Accuracy: 0.75 	time: 294.1
# Epoch: 40 	Training Loss: 0.579074 	Validation Loss: 0.617349 	Validation Accuracy: 0.73 	time: 291.7
# Epoch: 41 	Training Loss: 0.581115 	Validation Loss: 0.576510 	Validation Accuracy: 0.73 	time: 315.8
# Epoch: 42 	Training Loss: 0.564370 	Validation Loss: 0.582397 	Validation Accuracy: 0.75 	time: 298.4
# Epoch: 43 	Training Loss: 0.575614 	Validation Loss: 0.575883 	Validation Accuracy: 0.75 	time: 296.7
# Epoch: 44 	Training Loss: 0.577573 	Validation Loss: 0.590657 	Validation Accuracy: 0.73 	time: 291.0
# Epoch: 45 	Training Loss: 0.575563 	Validation Loss: 0.581319 	Validation Accuracy: 0.75 	time: 286.5
# Epoch: 46 	Training Loss: 0.579729 	Validation Loss: 0.579994 	Validation Accuracy: 0.76 	time: 289.0
# Epoch: 47 	Training Loss: 0.571608 	Validation Loss: 0.575622 	Validation Accuracy: 0.75 	time: 294.0
# Epoch: 48 	Training Loss: 0.576521 	Validation Loss: 0.570471 	Validation Accuracy: 0.76 	time: 293.0
# Validation loss decreased from 0.573319 to 0.570471. Model was saved
# Epoch: 49 	Training Loss: 0.574715 	Validation Loss: 0.596387 	Validation Accuracy: 0.73 	time: 294.5
# Epoch: 50 	Training Loss: 0.571698 	Validation Loss: 0.582758 	Validation Accuracy: 0.75 	time: 292.4
# Epoch: 51 	Training Loss: 0.572409 	Validation Loss: 0.596086 	Validation Accuracy: 0.74 	time: 290.8
# Epoch: 52 	Training Loss: 0.580280 	Validation Loss: 0.573909 	Validation Accuracy: 0.76 	time: 290.3
# Epoch: 53 	Training Loss: 0.570308 	Validation Loss: 0.571925 	Validation Accuracy: 0.77 	time: 293.6
# Epoch: 54 	Training Loss: 0.575111 	Validation Loss: 0.583083 	Validation Accuracy: 0.74 	time: 287.5
# Epoch: 55 	Training Loss: 0.571419 	Validation Loss: 0.598355 	Validation Accuracy: 0.74 	time: 284.1
# Epoch: 56 	Training Loss: 0.570390 	Validation Loss: 0.583161 	Validation Accuracy: 0.75 	time: 285.2
# Epoch: 57 	Training Loss: 0.565586 	Validation Loss: 0.585305 	Validation Accuracy: 0.75 	time: 275.7
# Epoch: 58 	Training Loss: 0.567435 	Validation Loss: 0.595240 	Validation Accuracy: 0.74 	time: 277.6
# use lr only one tenth of the original one to the last epoch
# early stop. return

# %%
# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer_v32.pt'))

# %%
from PIL import Image
from torch.autograd import Variable

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = data_transfer['train'].classes

def predict_class_transfer(img_path):
    # load the image and return the predicted breed
    img = Image.open(img_path)

    transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()
                               ]) 
    img = transform(img)
    img = img.unsqueeze(0) 

    img = Variable(img)

    img = img.to(device)
        
    prediction = model_transfer(img)  # Returns a Tensor of shape (batch, num class labels)
#     print(prediction)
#     print(class_names)
#     prediction = prediction.data.max(1, keepdim=True)[1]
    prediction = prediction.data.cpu().numpy().argmax()  # Our prediction will be the index of the class label with the largest value.
    prediction = class_names[prediction]
    return prediction 


# predict_class_transfer('../data/competition/02186.jpg')

# %%
#Get all test files

from glob import glob
import numpy as np

test_results = []

mango_files = np.array(glob("../data/competition/*"))

for idx, file in enumerate(mango_files):
    _ , filename = os.path.split(file)
    className = predict_class_transfer(file)
    test_results.append([filename, className])
    
# test_results[:3]

# %%
import csv

with open('results_v32.csv', 'w') as f:

    writer = csv.writer(f)
    
    for row in test_results:
        writer.writerow(row)

# %%
def test(loaders, model, criterion):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_transfer, model_transfer, criterion_transfer)
# Out:
# Test Loss: 0.602523
#
#
# Test Accuracy: 70% (66/93)
