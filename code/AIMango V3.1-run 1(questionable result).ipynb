# %% [markdown]
# # Hyperparameters
#
# #### batch_size = 128
# #### start_epoch = 0
# #### lr = 0.001
# #### valid_loss_stable_count = 10
#
# #### Make learning rate lr one tenth if the number of epochs in which validation loss doesn't decrease exceeds the paramter of valid_loss_stable_count.
#
# ### Result Accuracy on Sample Dataset is 75% , Test loss is 0.648536

# %%
TRAIN_CSV_PATH = '../C1-P1_Train Dev_fixed/train.csv'
VALID_CSV_PATH = '../C1-P1_Train Dev_fixed/dev.csv'
TEST_CSV_PATH = '../AIMango_sample/label.csv'

ORIGINAL_TRAIN_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Train/' 
ORIGINAL_VALID_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Dev/' 
ORIGINAL_TEST_DATA_PATH = '../AIMango_sample/sample_image/' 

TRAIN_DATA_PATH = '../data/train'
VALID_DATA_PATH = '../data/valid'
TEST_DATA_PATH = '../data/test'

# %%
import csv
import os
new_data = []
with open(TEST_CSV_PATH) as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        new_label = row[1][len(row[1])-1]
        new_data.append([row[0],new_label])


folder, filename = os.path.split(TEST_CSV_PATH)
NEW_TEST_CSV_PATH = os.path.join(folder, 'label_new.csv')
                                 
with open(NEW_TEST_CSV_PATH, 'w') as f:

    writer = csv.writer(f)
    
    for row in new_data:
        writer.writerow(row)

# %%
import csv
import os
from shutil import copyfile


# make file structure for training dataset
#
with open(TRAIN_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TRAIN_DATA_PATH, row[0])
        dest_path = os.path.join(TRAIN_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1
        
# make file structure for validation dataset
#
with open(VALID_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_VALID_DATA_PATH, row[0])
        dest_path = os.path.join(VALID_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# make file structure for validation dataset
#
with open(NEW_TEST_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TEST_DATA_PATH, row[0])
        dest_path = os.path.join(TEST_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# %%
import torch

from torchvision import datasets

import torchvision.transforms as transforms

from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# Hyperparameters

batch_size = 128
start_epoch = 0
lr = 0.001
valid_loss_stable_count = 10

transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.RandomHorizontalFlip(p=0.5),
                                transforms.RandomRotation(degrees=(-15, 15)),
                                transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
                                transforms.ToTensor(),
                                transforms.Normalize(
                                    mean=(0.485, 0.456, 0.406),
                                    std =(0.229, 0.224, 0.225))
                               ])
loaders_transfer = {}
data_transfer = {}

data_transfer['train'] = datasets.ImageFolder(TRAIN_DATA_PATH, transform=transform)
loaders_transfer['train'] = torch.utils.data.DataLoader(data_transfer['train'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=4)

data_transfer['valid'] = datasets.ImageFolder(VALID_DATA_PATH, transform=transform)
loaders_transfer['valid'] = torch.utils.data.DataLoader(data_transfer['valid'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=4)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
import torchvision.models as models
import torch.nn as nn

model_transfer = models.resnet152(pretrained=True).to(device)
    
for param in model_transfer.parameters():
    param.requires_grad = False   
    
model_transfer.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 3)).to(device)

# %%
import torch.optim as optim

criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = [optim.SGD(model_transfer.fc.parameters(), lr = lr, momentum = 0.9),
                      optim.SGD(model_transfer.fc.parameters(), lr = lr * 0.1, momentum = 0.9)]

# %%
import numpy as np
import time
import copy


# train the model
def train(n_epochs, loaders, model, optimizers, criterion, save_path):

    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    # Valid Loss Stable counter
    valid_loss_stable_counter = 0
    #optimizer index
    optim_idx = 0
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        optimizer = optimizers[optim_idx]
        
        start = time.time()
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders_transfer['train']):
            data, target = data.to(device), target.to(device)
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update accumulated training loss
            train_loss += loss.item()*data.size(0)
#             train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        valid_corrects = 0
        for batch_idx, (data, target) in enumerate(loaders_transfer['valid']):

            data, target = data.to(device), target.to(device)
            
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            _, preds = torch.max(output, 1)
            
            # calculate the batch loss
            loss = criterion(output, target)
            # update accumulated validation loss 
            valid_loss += loss.item()*data.size(0)
#             valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
    
            valid_corrects += torch.sum(preds == target.data)
        
        train_loss = train_loss/len(loaders_transfer['train'].dataset)
        valid_loss = valid_loss/len(loaders_transfer['valid'].dataset)
        
        epoch_acc = valid_corrects.double() / len(loaders_transfer['valid'].dataset)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tValidation Accuracy: {:.4f} \ttime: {:.1f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            epoch_acc,
            time.time() - start
            ))
        
        if valid_loss < valid_loss_min:
            print('Validation loss decreased from {:.6f} to {:.6f}. Model was saved'.format(
                valid_loss_min,
                valid_loss
            ))

            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(best_model_wts, 'model_transfer_v31.pt')


            valid_loss_min = valid_loss
            
            valid_loss_stable_counter = 0
        else:
            valid_loss_stable_counter += 1
            optim_idx = 1
    
    # return trained model
    return model

model_transfer = train(100, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, 'model_transfer.pt')
# Out:
# Epoch: 1 	Training Loss: 1.064065 	Validation Loss: 1.020472 	Validation Accuracy: 0.5850 	time: 135.1
# Validation loss decreased from inf to 1.020472. Model was saved
# Epoch: 2 	Training Loss: 0.981229 	Validation Loss: 0.939269 	Validation Accuracy: 0.6375 	time: 133.4
# Validation loss decreased from 1.020472 to 0.939269. Model was saved
# Epoch: 3 	Training Loss: 0.896884 	Validation Loss: 0.876669 	Validation Accuracy: 0.6100 	time: 134.7
# Validation loss decreased from 0.939269 to 0.876669. Model was saved
# Epoch: 4 	Training Loss: 0.828545 	Validation Loss: 0.798988 	Validation Accuracy: 0.6700 	time: 133.3
# Validation loss decreased from 0.876669 to 0.798988. Model was saved
# Epoch: 5 	Training Loss: 0.774061 	Validation Loss: 0.765037 	Validation Accuracy: 0.6750 	time: 134.9
# Validation loss decreased from 0.798988 to 0.765037. Model was saved
# Epoch: 6 	Training Loss: 0.733329 	Validation Loss: 0.721000 	Validation Accuracy: 0.6837 	time: 130.7
# Validation loss decreased from 0.765037 to 0.721000. Model was saved
# Epoch: 7 	Training Loss: 0.704156 	Validation Loss: 0.699925 	Validation Accuracy: 0.6925 	time: 133.1
# Validation loss decreased from 0.721000 to 0.699925. Model was saved
# Epoch: 8 	Training Loss: 0.692419 	Validation Loss: 0.694188 	Validation Accuracy: 0.6913 	time: 134.8
# Validation loss decreased from 0.699925 to 0.694188. Model was saved
# Epoch: 9 	Training Loss: 0.681670 	Validation Loss: 0.676042 	Validation Accuracy: 0.6950 	time: 131.5
# Validation loss decreased from 0.694188 to 0.676042. Model was saved
# Epoch: 10 	Training Loss: 0.677905 	Validation Loss: 0.666889 	Validation Accuracy: 0.6900 	time: 130.5
# Validation loss decreased from 0.676042 to 0.666889. Model was saved
# Epoch: 11 	Training Loss: 0.657161 	Validation Loss: 0.666049 	Validation Accuracy: 0.7037 	time: 132.3
# Validation loss decreased from 0.666889 to 0.666049. Model was saved
# Epoch: 12 	Training Loss: 0.652282 	Validation Loss: 0.657362 	Validation Accuracy: 0.7025 	time: 130.1
# Validation loss decreased from 0.666049 to 0.657362. Model was saved
# Epoch: 13 	Training Loss: 0.659693 	Validation Loss: 0.643500 	Validation Accuracy: 0.7075 	time: 135.4
# Validation loss decreased from 0.657362 to 0.643500. Model was saved
# Epoch: 14 	Training Loss: 0.644221 	Validation Loss: 0.641971 	Validation Accuracy: 0.7213 	time: 127.9
# Validation loss decreased from 0.643500 to 0.641971. Model was saved
# Epoch: 15 	Training Loss: 0.644651 	Validation Loss: 0.642222 	Validation Accuracy: 0.6875 	time: 134.7
# Epoch: 16 	Training Loss: 0.633522 	Validation Loss: 0.633891 	Validation Accuracy: 0.7188 	time: 131.0
# Validation loss decreased from 0.641971 to 0.633891. Model was saved
# Epoch: 17 	Training Loss: 0.637388 	Validation Loss: 0.651559 	Validation Accuracy: 0.7100 	time: 130.4
# Epoch: 18 	Training Loss: 0.639471 	Validation Loss: 0.634706 	Validation Accuracy: 0.7250 	time: 131.1
# Epoch: 19 	Training Loss: 0.632468 	Validation Loss: 0.636588 	Validation Accuracy: 0.7188 	time: 129.2
# Epoch: 20 	Training Loss: 0.625446 	Validation Loss: 0.646960 	Validation Accuracy: 0.7175 	time: 131.6
# Epoch: 21 	Training Loss: 0.633147 	Validation Loss: 0.634813 	Validation Accuracy: 0.7263 	time: 127.4
# Epoch: 22 	Training Loss: 0.642845 	Validation Loss: 0.640108 	Validation Accuracy: 0.7150 	time: 124.0
# Epoch: 23 	Training Loss: 0.631163 	Validation Loss: 0.646036 	Validation Accuracy: 0.7200 	time: 131.0
# Epoch: 24 	Training Loss: 0.638763 	Validation Loss: 0.644900 	Validation Accuracy: 0.7125 	time: 127.8
# Epoch: 25 	Training Loss: 0.630868 	Validation Loss: 0.637617 	Validation Accuracy: 0.7137 	time: 131.2
# Epoch: 26 	Training Loss: 0.632705 	Validation Loss: 0.636693 	Validation Accuracy: 0.7225 	time: 127.6
# Epoch: 27 	Training Loss: 0.638761 	Validation Loss: 0.631380 	Validation Accuracy: 0.7288 	time: 133.4
# Validation loss decreased from 0.633891 to 0.631380. Model was saved
# Epoch: 28 	Training Loss: 0.628874 	Validation Loss: 0.648876 	Validation Accuracy: 0.7137 	time: 131.7
# Epoch: 29 	Training Loss: 0.635034 	Validation Loss: 0.632357 	Validation Accuracy: 0.7213 	time: 129.3
# Epoch: 30 	Training Loss: 0.629176 	Validation Loss: 0.645502 	Validation Accuracy: 0.7288 	time: 128.9
# Epoch: 31 	Training Loss: 0.637453 	Validation Loss: 0.644808 	Validation Accuracy: 0.7225 	time: 131.2
# Epoch: 32 	Training Loss: 0.628809 	Validation Loss: 0.630316 	Validation Accuracy: 0.7338 	time: 130.0
# Validation loss decreased from 0.631380 to 0.630316. Model was saved
# Epoch: 33 	Training Loss: 0.633519 	Validation Loss: 0.628784 	Validation Accuracy: 0.7425 	time: 109.2
# Validation loss decreased from 0.630316 to 0.628784. Model was saved
# Epoch: 34 	Training Loss: 0.645380 	Validation Loss: 0.647520 	Validation Accuracy: 0.7225 	time: 82.7
# Epoch: 35 	Training Loss: 0.632200 	Validation Loss: 0.645828 	Validation Accuracy: 0.7213 	time: 81.8
# Epoch: 36 	Training Loss: 0.628546 	Validation Loss: 0.631552 	Validation Accuracy: 0.7163 	time: 82.5
# Epoch: 37 	Training Loss: 0.634644 	Validation Loss: 0.640935 	Validation Accuracy: 0.7113 	time: 80.9
# Epoch: 38 	Training Loss: 0.627032 	Validation Loss: 0.618144 	Validation Accuracy: 0.7300 	time: 81.1
# Validation loss decreased from 0.628784 to 0.618144. Model was saved
# Epoch: 39 	Training Loss: 0.635206 	Validation Loss: 0.627856 	Validation Accuracy: 0.7150 	time: 81.8
# Epoch: 40 	Training Loss: 0.630385 	Validation Loss: 0.645577 	Validation Accuracy: 0.7250 	time: 82.9
# Epoch: 41 	Training Loss: 0.630007 	Validation Loss: 0.637502 	Validation Accuracy: 0.7125 	time: 81.1
# Epoch: 42 	Training Loss: 0.630898 	Validation Loss: 0.625297 	Validation Accuracy: 0.7375 	time: 81.6
# Epoch: 43 	Training Loss: 0.628092 	Validation Loss: 0.632611 	Validation Accuracy: 0.7263 	time: 81.1
# Epoch: 44 	Training Loss: 0.635270 	Validation Loss: 0.617151 	Validation Accuracy: 0.7250 	time: 80.3
# Validation loss decreased from 0.618144 to 0.617151. Model was saved
# Epoch: 45 	Training Loss: 0.625739 	Validation Loss: 0.630096 	Validation Accuracy: 0.7137 	time: 83.0
# Epoch: 46 	Training Loss: 0.622989 	Validation Loss: 0.633035 	Validation Accuracy: 0.7238 	time: 82.7
# Epoch: 47 	Training Loss: 0.632276 	Validation Loss: 0.626941 	Validation Accuracy: 0.7188 	time: 83.5
# Epoch: 48 	Training Loss: 0.633871 	Validation Loss: 0.631364 	Validation Accuracy: 0.7225 	time: 82.4
# Epoch: 49 	Training Loss: 0.629180 	Validation Loss: 0.620436 	Validation Accuracy: 0.7275 	time: 83.6
# Epoch: 50 	Training Loss: 0.630390 	Validation Loss: 0.613239 	Validation Accuracy: 0.7200 	time: 81.3
# Validation loss decreased from 0.617151 to 0.613239. Model was saved
# Epoch: 51 	Training Loss: 0.630829 	Validation Loss: 0.640657 	Validation Accuracy: 0.7150 	time: 81.3
# Epoch: 52 	Training Loss: 0.634631 	Validation Loss: 0.646136 	Validation Accuracy: 0.7250 	time: 79.8
# Epoch: 53 	Training Loss: 0.626878 	Validation Loss: 0.632186 	Validation Accuracy: 0.7300 	time: 80.2
# Epoch: 54 	Training Loss: 0.631140 	Validation Loss: 0.627282 	Validation Accuracy: 0.7213 	time: 78.9
# Epoch: 55 	Training Loss: 0.629352 	Validation Loss: 0.640920 	Validation Accuracy: 0.7013 	time: 77.9
# Epoch: 56 	Training Loss: 0.626852 	Validation Loss: 0.620911 	Validation Accuracy: 0.7338 	time: 78.7
# Epoch: 57 	Training Loss: 0.627290 	Validation Loss: 0.630276 	Validation Accuracy: 0.7150 	time: 79.5
# Epoch: 58 	Training Loss: 0.622029 	Validation Loss: 0.621606 	Validation Accuracy: 0.7213 	time: 77.6
# Epoch: 59 	Training Loss: 0.624164 	Validation Loss: 0.630787 	Validation Accuracy: 0.7288 	time: 76.3
# Epoch: 60 	Training Loss: 0.625553 	Validation Loss: 0.614265 	Validation Accuracy: 0.7200 	time: 75.6
# Epoch: 61 	Training Loss: 0.626547 	Validation Loss: 0.631188 	Validation Accuracy: 0.7375 	time: 76.4
# Epoch: 62 	Training Loss: 0.629430 	Validation Loss: 0.640196 	Validation Accuracy: 0.7125 	time: 76.4
# Epoch: 63 	Training Loss: 0.620868 	Validation Loss: 0.645223 	Validation Accuracy: 0.7188 	time: 76.6
# Epoch: 64 	Training Loss: 0.625188 	Validation Loss: 0.625377 	Validation Accuracy: 0.7225 	time: 76.1
# Epoch: 65 	Training Loss: 0.624453 	Validation Loss: 0.625197 	Validation Accuracy: 0.7313 	time: 78.3
# Epoch: 66 	Training Loss: 0.620679 	Validation Loss: 0.616491 	Validation Accuracy: 0.7300 	time: 76.2
# Epoch: 67 	Training Loss: 0.625490 	Validation Loss: 0.619444 	Validation Accuracy: 0.7263 	time: 76.9
# Epoch: 68 	Training Loss: 0.626639 	Validation Loss: 0.627114 	Validation Accuracy: 0.7238 	time: 77.0
# Epoch: 69 	Training Loss: 0.626069 	Validation Loss: 0.643023 	Validation Accuracy: 0.7163 	time: 76.0
# Epoch: 70 	Training Loss: 0.625608 	Validation Loss: 0.645418 	Validation Accuracy: 0.7100 	time: 78.7
# Epoch: 71 	Training Loss: 0.623709 	Validation Loss: 0.619883 	Validation Accuracy: 0.7388 	time: 80.7
# Epoch: 72 	Training Loss: 0.628280 	Validation Loss: 0.631399 	Validation Accuracy: 0.7150 	time: 81.0
# Epoch: 73 	Training Loss: 0.623015 	Validation Loss: 0.632855 	Validation Accuracy: 0.7137 	time: 77.6
# Epoch: 74 	Training Loss: 0.622911 	Validation Loss: 0.629811 	Validation Accuracy: 0.7163 	time: 78.3
# Epoch: 75 	Training Loss: 0.622717 	Validation Loss: 0.630336 	Validation Accuracy: 0.7350 	time: 76.9
# Epoch: 76 	Training Loss: 0.619488 	Validation Loss: 0.623128 	Validation Accuracy: 0.7238 	time: 78.0
# Epoch: 77 	Training Loss: 0.619530 	Validation Loss: 0.629695 	Validation Accuracy: 0.7250 	time: 77.5
# Epoch: 78 	Training Loss: 0.618175 	Validation Loss: 0.630531 	Validation Accuracy: 0.7300 	time: 77.0
# Epoch: 79 	Training Loss: 0.619436 	Validation Loss: 0.635713 	Validation Accuracy: 0.7200 	time: 76.4
# Epoch: 80 	Training Loss: 0.627184 	Validation Loss: 0.608188 	Validation Accuracy: 0.7238 	time: 77.7
# Validation loss decreased from 0.613239 to 0.608188. Model was saved
# Epoch: 81 	Training Loss: 0.623389 	Validation Loss: 0.628012 	Validation Accuracy: 0.7263 	time: 78.2
# Epoch: 82 	Training Loss: 0.626405 	Validation Loss: 0.607378 	Validation Accuracy: 0.7288 	time: 77.2
# Validation loss decreased from 0.608188 to 0.607378. Model was saved
# Epoch: 83 	Training Loss: 0.620708 	Validation Loss: 0.625471 	Validation Accuracy: 0.7263 	time: 78.5
# Epoch: 84 	Training Loss: 0.627287 	Validation Loss: 0.611664 	Validation Accuracy: 0.7163 	time: 79.6
# Epoch: 85 	Training Loss: 0.617599 	Validation Loss: 0.627323 	Validation Accuracy: 0.7238 	time: 79.4
# Epoch: 86 	Training Loss: 0.624161 	Validation Loss: 0.644830 	Validation Accuracy: 0.7163 	time: 81.4

# %% [markdown]
# # Competition- Phase 1: generate the result csv file

# %%
from PIL import Image
from torch.autograd import Variable
import torchvision.transforms as transforms


# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = ['A','B','C']

def predict_class_transfer(img_path):
    # load the image and return the predicted breed
    img = Image.open(img_path)

    transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()
                               ]) 
    img = transform(img)
    img = img.unsqueeze(0) 

    img = Variable(img)

    img = img.to(device)
        
    prediction = model_transfer(img)  # Returns a Tensor of shape (batch, num class labels)
    prediction = prediction.data.cpu().numpy().argmax()  # Our prediction will be the index of the class label with the largest value.
    prediction = class_names[prediction]
    return prediction 


predict_class_transfer('../data/competition/02186.jpg')

# %%
#Get all test files

from glob import glob
import numpy as np

test_results = []

mango_files = np.array(glob("../data/competition/*"))

for idx, file in enumerate(mango_files):
    _ , filename = os.path.split(file)
    className = predict_class_transfer(file)
    test_results.append([filename, className])
    
# test_results[:3]

# %%
import csv

with open('results.csv', 'w') as f:

    writer = csv.writer(f)
    
    for row in test_results:
        writer.writerow(row)

# %% [markdown]
# # The following module can be run separately if trained weights are available

# %%
import torch
import torchvision.models as models
import torch.nn as nn
from torchvision import datasets
import torchvision.transforms as transforms
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_transfer = models.resnet152(pretrained=True).to(device)
    
model_transfer.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 3)).to(device)
model_transfer.load_state_dict(torch.load('model_transfer_v31.pt', map_location=device))

# %%
TEST_DATA_PATH = '../data/test'
transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()
                               ]) 

if not 'data_transfer' in locals():
    print("create empty data_transfer")
    data_transfer = {}
if not 'loaders_transfer' in locals():
    print("create empty loaders_transfer")
    loaders_transfer = {}
data_transfer['test'] = datasets.ImageFolder(TEST_DATA_PATH, transform=transform)
loaders_transfer['test'] = torch.utils.data.DataLoader(data_transfer['test'],
                                          batch_size=1,
                                          shuffle=True,
                                          num_workers=4)

import torch.optim as optim

criterion_transfer = nn.CrossEntropyLoss()

# %%
import numpy as np

def test(loaders, model, criterion):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_transfer, model_transfer, criterion_transfer)
