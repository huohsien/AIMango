# %%
TRAIN_CSV_PATH = '../C1-P1_Train Dev_fixed/train.csv'
VALID_CSV_PATH = '../C1-P1_Train Dev_fixed/dev.csv'
TEST_CSV_PATH = '../AIMango_sample/label.csv'

ORIGINAL_TRAIN_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Train/' 
ORIGINAL_VALID_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Dev/' 
ORIGINAL_TEST_DATA_PATH = '../AIMango_sample/sample_image/' 

TRAIN_DATA_PATH = '../data/train'
VALID_DATA_PATH = '../data/valid'
TEST_DATA_PATH = '../data/test'

# %%
import csv
import os
new_data = []
with open(TEST_CSV_PATH) as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        new_label = row[1][len(row[1])-1]
        new_data.append([row[0],new_label])


folder, filename = os.path.split(TEST_CSV_PATH)
NEW_TEST_CSV_PATH = os.path.join(folder, 'label_new.csv')
                                 
with open(NEW_TEST_CSV_PATH, 'w') as f:

    writer = csv.writer(f)
    
    for row in new_data:
        writer.writerow(row)

# %%
import csv
import os
from shutil import copyfile


# make file structure for training dataset
#
with open(TRAIN_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TRAIN_DATA_PATH, row[0])
        dest_path = os.path.join(TRAIN_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1
        
# make file structure for validation dataset
#
with open(VALID_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_VALID_DATA_PATH, row[0])
        dest_path = os.path.join(VALID_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# make file structure for validation dataset
#
with open(NEW_TEST_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TEST_DATA_PATH, row[0])
        dest_path = os.path.join(TEST_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# %%
import torch

from torchvision import datasets

import torchvision.transforms as transforms

from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# Hyperparameters

batch_size = 256
lr = 0.01
valid_accuracy_stable_count = 36

transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.RandomHorizontalFlip(p=0.5),
                                transforms.RandomRotation(degrees=(-15, 15)),
                                transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
                                transforms.ToTensor(),
                                transforms.Normalize(
                                    mean=(0.485, 0.456, 0.406),
                                    std =(0.229, 0.224, 0.225))
                               ])
loaders_transfer = {}
data_transfer = {}

data_transfer['train'] = datasets.ImageFolder(TRAIN_DATA_PATH, transform=transform)
loaders_transfer['train'] = torch.utils.data.DataLoader(data_transfer['train'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

data_transfer['valid'] = datasets.ImageFolder(VALID_DATA_PATH, transform=transform)
loaders_transfer['valid'] = torch.utils.data.DataLoader(data_transfer['valid'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)
data_transfer['test'] = datasets.ImageFolder(TEST_DATA_PATH, transform=transform)
loaders_transfer['test'] = torch.utils.data.DataLoader(data_transfer['test'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
import torchvision.models as models
import torch.nn as nn

model_transfer = models.resnet152(pretrained=True).to(device)
    
for param in model_transfer.parameters():
    param.requires_grad = False   
    
model_transfer.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 3)).to(device)

# %%
import torch.optim as optim
from torch.optim import lr_scheduler

criterion_transfer = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_transfer = optim.SGD(model_transfer.fc.parameters(), lr=lr, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_transfer, step_size=7, gamma=0.1)

# %%
import numpy as np
import time
import copy


# train the model
def train(n_epochs, loaders, model, optimizer, criterion, scheduler, save_path):

    best_acc = 0
    # Valid Loss Stable counter
    valid_accuracy_stable_counter = 0

    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        start = time.time()
        
        ###################
        # train the model #
        ###################
        model.train()
        scheduler.step()
        
        for batch_idx, (data, target) in enumerate(loaders_transfer['train']):
            data, target = data.to(device), target.to(device)
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update accumulated training loss
            train_loss += loss.item()*data.size(0)
#             train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        valid_corrects = 0
        for batch_idx, (data, target) in enumerate(loaders_transfer['valid']):

            data, target = data.to(device), target.to(device)
            
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            _, preds = torch.max(output, 1)
            
            # calculate the batch loss
            loss = criterion(output, target)
            # update accumulated validation loss 
            valid_loss += loss.item()*data.size(0)
#             valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
    
            valid_corrects += torch.sum(preds == target.data)
        
        train_loss = train_loss/len(loaders_transfer['train'].dataset)
        valid_loss = valid_loss/len(loaders_transfer['valid'].dataset)
        
        epoch_acc = valid_corrects.double() / len(loaders_transfer['valid'].dataset)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tValidation Accuracy: {:.2f} \ttime: {:.1f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            epoch_acc,
            time.time() - start
            ))
        if epoch_acc > best_acc:
            print('Accuracy increased from {:.6f} to {:.6f}. Model was saved'.format(
                best_acc,
                epoch_acc
            ))

            best_acc = epoch_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(best_model_wts, save_path)
            
            valid_accuracy_stable_counter = 0
        else:
            valid_accuracy_stable_counter += 1
            if valid_accuracy_stable_counter >= valid_accuracy_stable_count:
                print("early stop. return")
                return model
    
    # return trained model
    return model

model_transfer = train(100,
                       loaders_transfer,
                       model_transfer,
                       optimizer_transfer,
                       criterion_transfer,
                       exp_lr_scheduler,
                       'model_transfer_v32211.pt')
# Out:
# Epoch: 1 	Training Loss: 1.020195 	Validation Loss: 0.874692 	Validation Accuracy: 0.67 	time: 297.4
# Accuracy increased from 0.000000 to 0.665000. Model was saved
# Epoch: 2 	Training Loss: 0.790054 	Validation Loss: 0.686868 	Validation Accuracy: 0.70 	time: 291.7
# Accuracy increased from 0.665000 to 0.703750. Model was saved
# Epoch: 3 	Training Loss: 0.680985 	Validation Loss: 0.692359 	Validation Accuracy: 0.69 	time: 293.2
# Epoch: 4 	Training Loss: 0.663364 	Validation Loss: 0.638367 	Validation Accuracy: 0.72 	time: 292.7
# Accuracy increased from 0.703750 to 0.717500. Model was saved
# Epoch: 5 	Training Loss: 0.649230 	Validation Loss: 0.630002 	Validation Accuracy: 0.72 	time: 292.9
# Accuracy increased from 0.717500 to 0.725000. Model was saved
# Epoch: 6 	Training Loss: 0.643313 	Validation Loss: 0.641103 	Validation Accuracy: 0.72 	time: 287.5
# Epoch: 7 	Training Loss: 0.641423 	Validation Loss: 0.653346 	Validation Accuracy: 0.71 	time: 286.7
# Epoch: 8 	Training Loss: 0.632709 	Validation Loss: 0.642170 	Validation Accuracy: 0.70 	time: 287.2
# Epoch: 9 	Training Loss: 0.614729 	Validation Loss: 0.643196 	Validation Accuracy: 0.72 	time: 287.5
# Epoch: 10 	Training Loss: 0.611042 	Validation Loss: 0.624844 	Validation Accuracy: 0.71 	time: 289.8
# Epoch: 11 	Training Loss: 0.614166 	Validation Loss: 0.636173 	Validation Accuracy: 0.72 	time: 310.1
# Epoch: 12 	Training Loss: 0.615069 	Validation Loss: 0.651501 	Validation Accuracy: 0.72 	time: 301.5
# Epoch: 13 	Training Loss: 0.614016 	Validation Loss: 0.629995 	Validation Accuracy: 0.71 	time: 287.9
# Epoch: 14 	Training Loss: 0.612710 	Validation Loss: 0.620503 	Validation Accuracy: 0.73 	time: 282.5
# Accuracy increased from 0.725000 to 0.728750. Model was saved
# Epoch: 15 	Training Loss: 0.613438 	Validation Loss: 0.620248 	Validation Accuracy: 0.74 	time: 283.7
# Accuracy increased from 0.728750 to 0.738750. Model was saved
# Epoch: 16 	Training Loss: 0.604479 	Validation Loss: 0.620276 	Validation Accuracy: 0.74 	time: 282.1
# Epoch: 17 	Training Loss: 0.610149 	Validation Loss: 0.622470 	Validation Accuracy: 0.71 	time: 280.9
# Epoch: 18 	Training Loss: 0.611679 	Validation Loss: 0.603525 	Validation Accuracy: 0.73 	time: 283.0
# Epoch: 19 	Training Loss: 0.603341 	Validation Loss: 0.623576 	Validation Accuracy: 0.74 	time: 292.4
# Epoch: 20 	Training Loss: 0.608177 	Validation Loss: 0.628222 	Validation Accuracy: 0.71 	time: 292.9
# Epoch: 21 	Training Loss: 0.608376 	Validation Loss: 0.596332 	Validation Accuracy: 0.75 	time: 289.6
# Accuracy increased from 0.738750 to 0.746250. Model was saved
# Epoch: 22 	Training Loss: 0.603680 	Validation Loss: 0.632156 	Validation Accuracy: 0.72 	time: 280.2
# Epoch: 23 	Training Loss: 0.602779 	Validation Loss: 0.616452 	Validation Accuracy: 0.73 	time: 283.8
# Epoch: 24 	Training Loss: 0.614301 	Validation Loss: 0.610741 	Validation Accuracy: 0.74 	time: 288.0
# Epoch: 25 	Training Loss: 0.601415 	Validation Loss: 0.618343 	Validation Accuracy: 0.74 	time: 288.4
# Epoch: 26 	Training Loss: 0.612809 	Validation Loss: 0.607442 	Validation Accuracy: 0.73 	time: 288.1
# Epoch: 27 	Training Loss: 0.612590 	Validation Loss: 0.611122 	Validation Accuracy: 0.73 	time: 285.8
# Epoch: 28 	Training Loss: 0.613379 	Validation Loss: 0.620196 	Validation Accuracy: 0.73 	time: 291.5
# Epoch: 29 	Training Loss: 0.605972 	Validation Loss: 0.615387 	Validation Accuracy: 0.72 	time: 286.7
# Epoch: 30 	Training Loss: 0.612518 	Validation Loss: 0.630756 	Validation Accuracy: 0.72 	time: 286.8
# Epoch: 31 	Training Loss: 0.602816 	Validation Loss: 0.615410 	Validation Accuracy: 0.73 	time: 288.9
# Epoch: 32 	Training Loss: 0.606850 	Validation Loss: 0.618239 	Validation Accuracy: 0.71 	time: 287.8
# Epoch: 33 	Training Loss: 0.615230 	Validation Loss: 0.620422 	Validation Accuracy: 0.73 	time: 287.5
# Epoch: 34 	Training Loss: 0.613162 	Validation Loss: 0.631712 	Validation Accuracy: 0.71 	time: 288.9
# Epoch: 35 	Training Loss: 0.613317 	Validation Loss: 0.631398 	Validation Accuracy: 0.71 	time: 287.8
# Epoch: 36 	Training Loss: 0.604802 	Validation Loss: 0.622751 	Validation Accuracy: 0.72 	time: 288.2
# Epoch: 37 	Training Loss: 0.605559 	Validation Loss: 0.615949 	Validation Accuracy: 0.74 	time: 287.7
# Epoch: 38 	Training Loss: 0.610091 	Validation Loss: 0.617509 	Validation Accuracy: 0.74 	time: 286.0
# Epoch: 39 	Training Loss: 0.606688 	Validation Loss: 0.633690 	Validation Accuracy: 0.72 	time: 284.5
# Epoch: 40 	Training Loss: 0.609133 	Validation Loss: 0.623527 	Validation Accuracy: 0.72 	time: 286.6
# Epoch: 41 	Training Loss: 0.608381 	Validation Loss: 0.632724 	Validation Accuracy: 0.71 	time: 289.8
# Epoch: 42 	Training Loss: 0.609407 	Validation Loss: 0.637591 	Validation Accuracy: 0.73 	time: 290.6
# Epoch: 43 	Training Loss: 0.598276 	Validation Loss: 0.611456 	Validation Accuracy: 0.72 	time: 290.6
# Epoch: 44 	Training Loss: 0.606510 	Validation Loss: 0.623399 	Validation Accuracy: 0.72 	time: 289.6
# Epoch: 45 	Training Loss: 0.602414 	Validation Loss: 0.620632 	Validation Accuracy: 0.73 	time: 289.5
# Epoch: 46 	Training Loss: 0.606762 	Validation Loss: 0.600706 	Validation Accuracy: 0.75 	time: 287.8
# Epoch: 47 	Training Loss: 0.607295 	Validation Loss: 0.621553 	Validation Accuracy: 0.72 	time: 285.3
# Epoch: 48 	Training Loss: 0.604803 	Validation Loss: 0.604386 	Validation Accuracy: 0.73 	time: 285.2
# Epoch: 49 	Training Loss: 0.612810 	Validation Loss: 0.607530 	Validation Accuracy: 0.73 	time: 286.8
# Epoch: 50 	Training Loss: 0.610340 	Validation Loss: 0.604433 	Validation Accuracy: 0.73 	time: 286.2
# Epoch: 51 	Training Loss: 0.604340 	Validation Loss: 0.622224 	Validation Accuracy: 0.72 	time: 289.9
# Epoch: 52 	Training Loss: 0.606449 	Validation Loss: 0.615216 	Validation Accuracy: 0.73 	time: 288.2
# Epoch: 53 	Training Loss: 0.610400 	Validation Loss: 0.632294 	Validation Accuracy: 0.73 	time: 289.9
# Epoch: 54 	Training Loss: 0.607984 	Validation Loss: 0.622820 	Validation Accuracy: 0.72 	time: 288.8
# Epoch: 55 	Training Loss: 0.607060 	Validation Loss: 0.607163 	Validation Accuracy: 0.72 	time: 291.9
# Epoch: 56 	Training Loss: 0.608425 	Validation Loss: 0.623363 	Validation Accuracy: 0.74 	time: 290.6
# Epoch: 57 	Training Loss: 0.608455 	Validation Loss: 0.594346 	Validation Accuracy: 0.74 	time: 291.1
# early stop. return

# %%
# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer_v32211.pt'))

# %%
from PIL import Image
from torch.autograd import Variable

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = data_transfer['train'].classes

def predict_class_transfer(img_path):
    # load the image and return the predicted breed
    img = Image.open(img_path)

    transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()
                               ]) 
    img = transform(img)
    img = img.unsqueeze(0) 

    img = Variable(img)

    img = img.to(device)
        
    prediction = model_transfer(img)  # Returns a Tensor of shape (batch, num class labels)
#     print(prediction)
#     print(class_names)
#     prediction = prediction.data.max(1, keepdim=True)[1]
    prediction = prediction.data.cpu().numpy().argmax()  # Our prediction will be the index of the class label with the largest value.
    prediction = class_names[prediction]
    return prediction 


# predict_class_transfer('../data/competition/02186.jpg')

# %%
#Get all test files

from glob import glob
import numpy as np

test_results = []

mango_files = np.array(glob("../data/competition/*"))

for idx, file in enumerate(mango_files):
    _ , filename = os.path.split(file)
    className = predict_class_transfer(file)
    test_results.append([filename, className])
    
# test_results[:3]

# %%
import csv

with open('results_v32211.csv', 'w') as f:

    writer = csv.writer(f)
    
    for row in test_results:
        writer.writerow(row)

# %%
def test(loaders, model, criterion):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_transfer, model_transfer, criterion_transfer)
# Out:
# Test Loss: 0.609594
#
#
# Test Accuracy: 74% (69/93)
