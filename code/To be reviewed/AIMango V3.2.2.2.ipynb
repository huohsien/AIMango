# %%
TRAIN_CSV_PATH = '../C1-P1_Train Dev_fixed/train.csv'
VALID_CSV_PATH = '../C1-P1_Train Dev_fixed/dev.csv'
TEST_CSV_PATH = '../AIMango_sample/label.csv'

ORIGINAL_TRAIN_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Train/' 
ORIGINAL_VALID_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Dev/' 
ORIGINAL_TEST_DATA_PATH = '../AIMango_sample/sample_image/' 

TRAIN_DATA_PATH = '../data/train'
VALID_DATA_PATH = '../data/valid'
TEST_DATA_PATH = '../data/test'

# %%
import csv
import os
new_data = []
with open(TEST_CSV_PATH) as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        new_label = row[1][len(row[1])-1]
        new_data.append([row[0],new_label])


folder, filename = os.path.split(TEST_CSV_PATH)
NEW_TEST_CSV_PATH = os.path.join(folder, 'label_new.csv')
                                 
with open(NEW_TEST_CSV_PATH, 'w') as f:

    writer = csv.writer(f)
    
    for row in new_data:
        writer.writerow(row)

# %%
import csv
import os
from shutil import copyfile


# make file structure for training dataset
#
with open(TRAIN_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TRAIN_DATA_PATH, row[0])
        dest_path = os.path.join(TRAIN_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1
        
# make file structure for validation dataset
#
with open(VALID_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_VALID_DATA_PATH, row[0])
        dest_path = os.path.join(VALID_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# make file structure for validation dataset
#
with open(NEW_TEST_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TEST_DATA_PATH, row[0])
        dest_path = os.path.join(TEST_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# %%
import torch

from torchvision import datasets

import torchvision.transforms as transforms

from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# Hyperparameters

batch_size = 64
lr = 0.001
valid_accuracy_stable_count = 36

transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.RandomHorizontalFlip(p=0.5),
                                transforms.RandomRotation(degrees=(-15, 15)),
                                transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
                                transforms.ToTensor(),
                                transforms.Normalize(
                                    mean=(0.485, 0.456, 0.406),
                                    std =(0.229, 0.224, 0.225))
                               ])
loaders_transfer = {}
data_transfer = {}

data_transfer['train'] = datasets.ImageFolder(TRAIN_DATA_PATH, transform=transform)
loaders_transfer['train'] = torch.utils.data.DataLoader(data_transfer['train'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

data_transfer['valid'] = datasets.ImageFolder(VALID_DATA_PATH, transform=transform)
loaders_transfer['valid'] = torch.utils.data.DataLoader(data_transfer['valid'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)
data_transfer['test'] = datasets.ImageFolder(TEST_DATA_PATH, transform=transform)
loaders_transfer['test'] = torch.utils.data.DataLoader(data_transfer['test'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
import torchvision.models as models
import torch.nn as nn

model_transfer = models.resnet152(pretrained=True).to(device)
    
for param in model_transfer.parameters():
    param.requires_grad = False   
    
model_transfer.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 3)).to(device)

# %%
import torch.optim as optim
from torch.optim import lr_scheduler

criterion_transfer = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_transfer = optim.SGD(model_transfer.fc.parameters(), lr=lr, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_transfer, step_size=7, gamma=0.1)

# %%
import numpy as np
import time
import copy


# train the model
def train(n_epochs, loaders, model, optimizer, criterion, scheduler, save_path):

    best_acc = 0
    # Valid Loss Stable counter
    valid_accuracy_stable_counter = 0

    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        start = time.time()
        
        ###################
        # train the model #
        ###################
        model.train()
        scheduler.step()
        
        for batch_idx, (data, target) in enumerate(loaders_transfer['train']):
            data, target = data.to(device), target.to(device)
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update accumulated training loss
            train_loss += loss.item()*data.size(0)
#             train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        valid_corrects = 0
        for batch_idx, (data, target) in enumerate(loaders_transfer['valid']):

            data, target = data.to(device), target.to(device)
            
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            _, preds = torch.max(output, 1)
            
            # calculate the batch loss
            loss = criterion(output, target)
            # update accumulated validation loss 
            valid_loss += loss.item()*data.size(0)
#             valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
    
            valid_corrects += torch.sum(preds == target.data)
        
        train_loss = train_loss/len(loaders_transfer['train'].dataset)
        valid_loss = valid_loss/len(loaders_transfer['valid'].dataset)
        
        epoch_acc = valid_corrects.double() / len(loaders_transfer['valid'].dataset)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tValidation Accuracy: {:.2f} \ttime: {:.1f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            epoch_acc,
            time.time() - start
            ))
        if epoch_acc > best_acc:
            print('Accuracy increased from {:.6f} to {:.6f}. Model was saved'.format(
                best_acc,
                epoch_acc
            ))

            best_acc = epoch_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(best_model_wts, save_path)
            
            valid_accuracy_stable_counter = 0
        else:
            valid_accuracy_stable_counter += 1
            if valid_accuracy_stable_counter >= valid_accuracy_stable_count:
                print("early stop. return")
                return model
    
    # return trained model
    return model

model_transfer = train(100,
                       loaders_transfer,
                       model_transfer,
                       optimizer_transfer,
                       criterion_transfer,
                       exp_lr_scheduler,
                       'model_transfer_v3222.pt')
# Out:
# Epoch: 1 	Training Loss: 1.039773 	Validation Loss: 0.967893 	Validation Accuracy: 0.62 	time: 292.8
# Accuracy increased from 0.000000 to 0.617500. Model was saved
# Epoch: 2 	Training Loss: 0.876827 	Validation Loss: 0.809213 	Validation Accuracy: 0.67 	time: 289.6
# Accuracy increased from 0.617500 to 0.665000. Model was saved
# Epoch: 3 	Training Loss: 0.761395 	Validation Loss: 0.732819 	Validation Accuracy: 0.66 	time: 290.6
# Epoch: 4 	Training Loss: 0.714429 	Validation Loss: 0.688355 	Validation Accuracy: 0.68 	time: 286.5
# Accuracy increased from 0.665000 to 0.677500. Model was saved
# Epoch: 5 	Training Loss: 0.681580 	Validation Loss: 0.689280 	Validation Accuracy: 0.69 	time: 290.3
# Accuracy increased from 0.677500 to 0.686250. Model was saved
# Epoch: 6 	Training Loss: 0.672855 	Validation Loss: 0.660008 	Validation Accuracy: 0.72 	time: 290.4
# Accuracy increased from 0.686250 to 0.716250. Model was saved
# Epoch: 7 	Training Loss: 0.679416 	Validation Loss: 0.699580 	Validation Accuracy: 0.66 	time: 288.7
# Epoch: 8 	Training Loss: 0.655013 	Validation Loss: 0.656392 	Validation Accuracy: 0.70 	time: 285.2
# Epoch: 9 	Training Loss: 0.647526 	Validation Loss: 0.656864 	Validation Accuracy: 0.72 	time: 286.5
# Accuracy increased from 0.716250 to 0.717500. Model was saved
# Epoch: 10 	Training Loss: 0.641569 	Validation Loss: 0.650748 	Validation Accuracy: 0.71 	time: 288.4
# Epoch: 11 	Training Loss: 0.649822 	Validation Loss: 0.653696 	Validation Accuracy: 0.70 	time: 289.0
# Epoch: 12 	Training Loss: 0.653079 	Validation Loss: 0.632891 	Validation Accuracy: 0.71 	time: 285.3
# Epoch: 13 	Training Loss: 0.650025 	Validation Loss: 0.644757 	Validation Accuracy: 0.71 	time: 287.5
# Epoch: 14 	Training Loss: 0.644962 	Validation Loss: 0.648274 	Validation Accuracy: 0.71 	time: 289.0
# Epoch: 15 	Training Loss: 0.643263 	Validation Loss: 0.642478 	Validation Accuracy: 0.72 	time: 285.9
# Accuracy increased from 0.717500 to 0.718750. Model was saved
# Epoch: 16 	Training Loss: 0.646490 	Validation Loss: 0.636595 	Validation Accuracy: 0.72 	time: 286.9
# Epoch: 17 	Training Loss: 0.639840 	Validation Loss: 0.637521 	Validation Accuracy: 0.72 	time: 288.5
# Accuracy increased from 0.718750 to 0.721250. Model was saved
# Epoch: 18 	Training Loss: 0.644606 	Validation Loss: 0.646852 	Validation Accuracy: 0.72 	time: 290.6
# Epoch: 19 	Training Loss: 0.641541 	Validation Loss: 0.653573 	Validation Accuracy: 0.71 	time: 288.2
# Epoch: 20 	Training Loss: 0.647868 	Validation Loss: 0.644724 	Validation Accuracy: 0.70 	time: 293.0
# Epoch: 21 	Training Loss: 0.639046 	Validation Loss: 0.639863 	Validation Accuracy: 0.70 	time: 293.0
# Epoch: 22 	Training Loss: 0.644182 	Validation Loss: 0.656131 	Validation Accuracy: 0.70 	time: 287.2
# Epoch: 23 	Training Loss: 0.641349 	Validation Loss: 0.658573 	Validation Accuracy: 0.71 	time: 285.8
# Epoch: 24 	Training Loss: 0.645289 	Validation Loss: 0.643542 	Validation Accuracy: 0.72 	time: 286.2
# Epoch: 25 	Training Loss: 0.648905 	Validation Loss: 0.639318 	Validation Accuracy: 0.73 	time: 283.6
# Accuracy increased from 0.721250 to 0.727500. Model was saved
# Epoch: 26 	Training Loss: 0.645560 	Validation Loss: 0.652488 	Validation Accuracy: 0.71 	time: 283.9
# Epoch: 27 	Training Loss: 0.641907 	Validation Loss: 0.640393 	Validation Accuracy: 0.72 	time: 281.6
# Epoch: 28 	Training Loss: 0.644099 	Validation Loss: 0.667171 	Validation Accuracy: 0.71 	time: 280.7
# Epoch: 29 	Training Loss: 0.645604 	Validation Loss: 0.662151 	Validation Accuracy: 0.71 	time: 281.4
# Epoch: 30 	Training Loss: 0.644528 	Validation Loss: 0.636597 	Validation Accuracy: 0.72 	time: 285.0
# Epoch: 31 	Training Loss: 0.639687 	Validation Loss: 0.653499 	Validation Accuracy: 0.70 	time: 286.4
# Epoch: 32 	Training Loss: 0.645543 	Validation Loss: 0.658531 	Validation Accuracy: 0.71 	time: 287.8
# Epoch: 33 	Training Loss: 0.643088 	Validation Loss: 0.664326 	Validation Accuracy: 0.70 	time: 289.0
# Epoch: 34 	Training Loss: 0.642952 	Validation Loss: 0.641463 	Validation Accuracy: 0.72 	time: 291.7
# Epoch: 35 	Training Loss: 0.646678 	Validation Loss: 0.613548 	Validation Accuracy: 0.74 	time: 293.4
# Accuracy increased from 0.727500 to 0.736250. Model was saved
# Epoch: 36 	Training Loss: 0.643424 	Validation Loss: 0.644381 	Validation Accuracy: 0.70 	time: 294.9
# Epoch: 37 	Training Loss: 0.642597 	Validation Loss: 0.645169 	Validation Accuracy: 0.72 	time: 293.1
# Epoch: 38 	Training Loss: 0.646210 	Validation Loss: 0.638379 	Validation Accuracy: 0.71 	time: 289.6
# Epoch: 39 	Training Loss: 0.640145 	Validation Loss: 0.657973 	Validation Accuracy: 0.69 	time: 287.7
# Epoch: 40 	Training Loss: 0.645926 	Validation Loss: 0.640269 	Validation Accuracy: 0.71 	time: 291.1
# Epoch: 41 	Training Loss: 0.644400 	Validation Loss: 0.665714 	Validation Accuracy: 0.70 	time: 291.9
# Epoch: 42 	Training Loss: 0.643848 	Validation Loss: 0.644636 	Validation Accuracy: 0.73 	time: 288.9
# Epoch: 43 	Training Loss: 0.642754 	Validation Loss: 0.639825 	Validation Accuracy: 0.73 	time: 287.0
# Epoch: 44 	Training Loss: 0.641660 	Validation Loss: 0.651447 	Validation Accuracy: 0.72 	time: 288.9
# Epoch: 45 	Training Loss: 0.649122 	Validation Loss: 0.664859 	Validation Accuracy: 0.70 	time: 291.9
# Epoch: 46 	Training Loss: 0.650334 	Validation Loss: 0.650826 	Validation Accuracy: 0.72 	time: 289.5
# Epoch: 47 	Training Loss: 0.637290 	Validation Loss: 0.651751 	Validation Accuracy: 0.71 	time: 290.3
# Epoch: 48 	Training Loss: 0.638394 	Validation Loss: 0.632008 	Validation Accuracy: 0.71 	time: 291.3
# Epoch: 49 	Training Loss: 0.642525 	Validation Loss: 0.645211 	Validation Accuracy: 0.71 	time: 291.7
# Epoch: 50 	Training Loss: 0.640072 	Validation Loss: 0.639016 	Validation Accuracy: 0.73 	time: 293.0
# Epoch: 51 	Training Loss: 0.650114 	Validation Loss: 0.649725 	Validation Accuracy: 0.70 	time: 291.7
# Epoch: 52 	Training Loss: 0.648266 	Validation Loss: 0.649642 	Validation Accuracy: 0.71 	time: 289.6
# Epoch: 53 	Training Loss: 0.638374 	Validation Loss: 0.647392 	Validation Accuracy: 0.72 	time: 285.0
# Epoch: 54 	Training Loss: 0.650474 	Validation Loss: 0.641961 	Validation Accuracy: 0.73 	time: 287.1
# Epoch: 55 	Training Loss: 0.638165 	Validation Loss: 0.653453 	Validation Accuracy: 0.71 	time: 290.9
# Epoch: 56 	Training Loss: 0.639245 	Validation Loss: 0.654502 	Validation Accuracy: 0.69 	time: 291.7
# Epoch: 57 	Training Loss: 0.643269 	Validation Loss: 0.644318 	Validation Accuracy: 0.72 	time: 296.0
# Epoch: 58 	Training Loss: 0.641219 	Validation Loss: 0.627827 	Validation Accuracy: 0.70 	time: 292.7
# Epoch: 59 	Training Loss: 0.641645 	Validation Loss: 0.638982 	Validation Accuracy: 0.73 	time: 295.0
# Epoch: 60 	Training Loss: 0.632364 	Validation Loss: 0.657885 	Validation Accuracy: 0.70 	time: 290.7
# Epoch: 61 	Training Loss: 0.642260 	Validation Loss: 0.643141 	Validation Accuracy: 0.72 	time: 297.5
# Epoch: 62 	Training Loss: 0.643764 	Validation Loss: 0.637164 	Validation Accuracy: 0.71 	time: 293.5
# Epoch: 63 	Training Loss: 0.642297 	Validation Loss: 0.662260 	Validation Accuracy: 0.70 	time: 294.9
# Epoch: 64 	Training Loss: 0.643067 	Validation Loss: 0.667848 	Validation Accuracy: 0.70 	time: 295.4
# Epoch: 65 	Training Loss: 0.647263 	Validation Loss: 0.639747 	Validation Accuracy: 0.71 	time: 291.7
# Epoch: 66 	Training Loss: 0.641250 	Validation Loss: 0.631755 	Validation Accuracy: 0.72 	time: 290.1
# Epoch: 67 	Training Loss: 0.638582 	Validation Loss: 0.659493 	Validation Accuracy: 0.70 	time: 289.3
# Epoch: 68 	Training Loss: 0.639070 	Validation Loss: 0.639645 	Validation Accuracy: 0.71 	time: 287.6
# Epoch: 69 	Training Loss: 0.645636 	Validation Loss: 0.647483 	Validation Accuracy: 0.71 	time: 287.6
# Epoch: 70 	Training Loss: 0.641298 	Validation Loss: 0.648471 	Validation Accuracy: 0.71 	time: 289.3
# Epoch: 71 	Training Loss: 0.638876 	Validation Loss: 0.642901 	Validation Accuracy: 0.72 	time: 288.2
# early stop. return

# %%
# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer_v3222.pt'))

# %%
from PIL import Image
from torch.autograd import Variable

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = data_transfer['train'].classes

def predict_class_transfer(img_path):
    # load the image and return the predicted breed
    img = Image.open(img_path)

    transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()
                               ]) 
    img = transform(img)
    img = img.unsqueeze(0) 

    img = Variable(img)

    img = img.to(device)
        
    prediction = model_transfer(img)  # Returns a Tensor of shape (batch, num class labels)
#     print(prediction)
#     print(class_names)
#     prediction = prediction.data.max(1, keepdim=True)[1]
    prediction = prediction.data.cpu().numpy().argmax()  # Our prediction will be the index of the class label with the largest value.
    prediction = class_names[prediction]
    return prediction 


# predict_class_transfer('../data/competition/02186.jpg')

# %%
#Get all test files

from glob import glob
import numpy as np

test_results = []

mango_files = np.array(glob("../data/competition/*"))

for idx, file in enumerate(mango_files):
    _ , filename = os.path.split(file)
    className = predict_class_transfer(file)
    test_results.append([filename, className])
    
# test_results[:3]

# %%
import csv

with open('results_v3222.csv', 'w') as f:

    writer = csv.writer(f)
    
    for row in test_results:
        writer.writerow(row)

# %%
def test(loaders, model, criterion):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_transfer, model_transfer, criterion_transfer)
# Out:
# Test Loss: 0.622820
#
#
# Test Accuracy: 63% (59/93)
