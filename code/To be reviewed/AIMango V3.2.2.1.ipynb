# %%
TRAIN_CSV_PATH = '../C1-P1_Train Dev_fixed/train.csv'
VALID_CSV_PATH = '../C1-P1_Train Dev_fixed/dev.csv'
TEST_CSV_PATH = '../AIMango_sample/label.csv'

ORIGINAL_TRAIN_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Train/' 
ORIGINAL_VALID_DATA_PATH = '../C1-P1_Train Dev_fixed/C1-P1_Dev/' 
ORIGINAL_TEST_DATA_PATH = '../AIMango_sample/sample_image/' 

TRAIN_DATA_PATH = '../data/train'
VALID_DATA_PATH = '../data/valid'
TEST_DATA_PATH = '../data/test'

# %%
import csv
import os
new_data = []
with open(TEST_CSV_PATH) as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        new_label = row[1][len(row[1])-1]
        new_data.append([row[0],new_label])


folder, filename = os.path.split(TEST_CSV_PATH)
NEW_TEST_CSV_PATH = os.path.join(folder, 'label_new.csv')
                                 
with open(NEW_TEST_CSV_PATH, 'w') as f:

    writer = csv.writer(f)
    
    for row in new_data:
        writer.writerow(row)

# %%
import csv
import os
from shutil import copyfile


# make file structure for training dataset
#
with open(TRAIN_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TRAIN_DATA_PATH, row[0])
        dest_path = os.path.join(TRAIN_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1
        
# make file structure for validation dataset
#
with open(VALID_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_VALID_DATA_PATH, row[0])
        dest_path = os.path.join(VALID_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# make file structure for validation dataset
#
with open(NEW_TEST_CSV_PATH) as csv_file:

    csv_reader = csv.reader(csv_file, delimiter=',')

    line_count = 0
    for row in csv_reader:

        if line_count == 0:
            line_count += 1
            continue  #header

        src_path = os.path.join(ORIGINAL_TEST_DATA_PATH, row[0])
        dest_path = os.path.join(TEST_DATA_PATH, row[1], row[0])
        if not os.path.isfile(dest_path):
            copyfile(src_path, dest_path)
        
        line_count += 1

# %%
import torch

from torchvision import datasets

import torchvision.transforms as transforms

from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# Hyperparameters

batch_size = 256
lr = 0.001
valid_accuracy_stable_count = 36

transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.RandomHorizontalFlip(p=0.5),
                                transforms.RandomRotation(degrees=(-15, 15)),
                                transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
                                transforms.ToTensor(),
                                transforms.Normalize(
                                    mean=(0.485, 0.456, 0.406),
                                    std =(0.229, 0.224, 0.225))
                               ])
loaders_transfer = {}
data_transfer = {}

data_transfer['train'] = datasets.ImageFolder(TRAIN_DATA_PATH, transform=transform)
loaders_transfer['train'] = torch.utils.data.DataLoader(data_transfer['train'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

data_transfer['valid'] = datasets.ImageFolder(VALID_DATA_PATH, transform=transform)
loaders_transfer['valid'] = torch.utils.data.DataLoader(data_transfer['valid'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)
data_transfer['test'] = datasets.ImageFolder(TEST_DATA_PATH, transform=transform)
loaders_transfer['test'] = torch.utils.data.DataLoader(data_transfer['test'],
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=1)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
import torchvision.models as models
import torch.nn as nn

model_transfer = models.resnet152(pretrained=True).to(device)
    
for param in model_transfer.parameters():
    param.requires_grad = False   
    
model_transfer.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 3)).to(device)

# %%
import torch.optim as optim
from torch.optim import lr_scheduler

criterion_transfer = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_transfer = optim.SGD(model_transfer.fc.parameters(), lr=lr, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_transfer, step_size=7, gamma=0.1)

# %%
import numpy as np
import time
import copy


# train the model
def train(n_epochs, loaders, model, optimizer, criterion, scheduler, save_path):

    best_acc = 0
    # Valid Loss Stable counter
    valid_accuracy_stable_counter = 0

    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        start = time.time()
        
        ###################
        # train the model #
        ###################
        model.train()
        scheduler.step()
        
        for batch_idx, (data, target) in enumerate(loaders_transfer['train']):
            data, target = data.to(device), target.to(device)
            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update accumulated training loss
            train_loss += loss.item()*data.size(0)
#             train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        valid_corrects = 0
        for batch_idx, (data, target) in enumerate(loaders_transfer['valid']):

            data, target = data.to(device), target.to(device)
            
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            _, preds = torch.max(output, 1)
            
            # calculate the batch loss
            loss = criterion(output, target)
            # update accumulated validation loss 
            valid_loss += loss.item()*data.size(0)
#             valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
    
            valid_corrects += torch.sum(preds == target.data)
        
        train_loss = train_loss/len(loaders_transfer['train'].dataset)
        valid_loss = valid_loss/len(loaders_transfer['valid'].dataset)
        
        epoch_acc = valid_corrects.double() / len(loaders_transfer['valid'].dataset)
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tValidation Accuracy: {:.2f} \ttime: {:.1f}'.format(
            epoch, 
            train_loss,
            valid_loss,
            epoch_acc,
            time.time() - start
            ))
        if epoch_acc > best_acc:
            print('Accuracy increased from {:.6f} to {:.6f}. Model was saved'.format(
                best_acc,
                epoch_acc
            ))

            best_acc = epoch_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(best_model_wts, save_path)
            
            valid_accuracy_stable_counter = 0
        else:
            valid_accuracy_stable_counter += 1
            if valid_accuracy_stable_counter >= valid_accuracy_stable_count:
                print("early stop. return")
                return model
    
    # return trained model
    return model

model_transfer = train(100,
                       loaders_transfer,
                       model_transfer,
                       optimizer_transfer,
                       criterion_transfer,
                       exp_lr_scheduler,
                       'model_transfer_v3221.pt')
# Out:
# Epoch: 1 	Training Loss: 1.084895 	Validation Loss: 1.070401 	Validation Accuracy: 0.37 	time: 292.3
# Accuracy increased from 0.000000 to 0.372500. Model was saved
# Epoch: 2 	Training Loss: 1.048142 	Validation Loss: 1.033556 	Validation Accuracy: 0.52 	time: 289.5
# Accuracy increased from 0.372500 to 0.521250. Model was saved
# Epoch: 3 	Training Loss: 1.006218 	Validation Loss: 0.988706 	Validation Accuracy: 0.59 	time: 291.0
# Accuracy increased from 0.521250 to 0.593750. Model was saved
# Epoch: 4 	Training Loss: 0.961015 	Validation Loss: 0.944004 	Validation Accuracy: 0.63 	time: 287.3
# Accuracy increased from 0.593750 to 0.630000. Model was saved
# Epoch: 5 	Training Loss: 0.919101 	Validation Loss: 0.908429 	Validation Accuracy: 0.64 	time: 289.5
# Accuracy increased from 0.630000 to 0.635000. Model was saved
# Epoch: 6 	Training Loss: 0.877635 	Validation Loss: 0.861166 	Validation Accuracy: 0.66 	time: 291.2
# Accuracy increased from 0.635000 to 0.660000. Model was saved
# Epoch: 7 	Training Loss: 0.841067 	Validation Loss: 0.834463 	Validation Accuracy: 0.67 	time: 288.4
# Accuracy increased from 0.660000 to 0.666250. Model was saved
# Epoch: 8 	Training Loss: 0.821873 	Validation Loss: 0.832004 	Validation Accuracy: 0.67 	time: 285.1
# Accuracy increased from 0.666250 to 0.672500. Model was saved
# Epoch: 9 	Training Loss: 0.815158 	Validation Loss: 0.823526 	Validation Accuracy: 0.67 	time: 286.5
# Accuracy increased from 0.672500 to 0.673750. Model was saved
# Epoch: 10 	Training Loss: 0.814120 	Validation Loss: 0.822289 	Validation Accuracy: 0.67 	time: 288.1
# Epoch: 11 	Training Loss: 0.807651 	Validation Loss: 0.818753 	Validation Accuracy: 0.66 	time: 289.3
# Epoch: 12 	Training Loss: 0.806696 	Validation Loss: 0.817791 	Validation Accuracy: 0.66 	time: 285.8
# Epoch: 13 	Training Loss: 0.805141 	Validation Loss: 0.814654 	Validation Accuracy: 0.67 	time: 287.7
# Epoch: 14 	Training Loss: 0.802565 	Validation Loss: 0.811762 	Validation Accuracy: 0.68 	time: 290.5
# Accuracy increased from 0.673750 to 0.675000. Model was saved
# Epoch: 15 	Training Loss: 0.798844 	Validation Loss: 0.816345 	Validation Accuracy: 0.66 	time: 287.0
# Epoch: 16 	Training Loss: 0.801165 	Validation Loss: 0.819416 	Validation Accuracy: 0.67 	time: 287.0
# Epoch: 17 	Training Loss: 0.800385 	Validation Loss: 0.802166 	Validation Accuracy: 0.68 	time: 288.0
# Accuracy increased from 0.675000 to 0.681250. Model was saved
# Epoch: 18 	Training Loss: 0.798037 	Validation Loss: 0.812315 	Validation Accuracy: 0.66 	time: 290.5
# Epoch: 19 	Training Loss: 0.800648 	Validation Loss: 0.816295 	Validation Accuracy: 0.66 	time: 288.7
# Epoch: 20 	Training Loss: 0.800995 	Validation Loss: 0.808922 	Validation Accuracy: 0.67 	time: 293.4
# Epoch: 21 	Training Loss: 0.796405 	Validation Loss: 0.811693 	Validation Accuracy: 0.68 	time: 293.8
# Epoch: 22 	Training Loss: 0.796753 	Validation Loss: 0.814278 	Validation Accuracy: 0.66 	time: 287.9
# Epoch: 23 	Training Loss: 0.796272 	Validation Loss: 0.813106 	Validation Accuracy: 0.68 	time: 286.0
# Epoch: 24 	Training Loss: 0.800194 	Validation Loss: 0.805136 	Validation Accuracy: 0.69 	time: 285.9
# Accuracy increased from 0.681250 to 0.685000. Model was saved
# Epoch: 25 	Training Loss: 0.798176 	Validation Loss: 0.801373 	Validation Accuracy: 0.67 	time: 285.5
# Epoch: 26 	Training Loss: 0.799239 	Validation Loss: 0.804601 	Validation Accuracy: 0.68 	time: 282.9
# Epoch: 27 	Training Loss: 0.797337 	Validation Loss: 0.810461 	Validation Accuracy: 0.67 	time: 281.4
# Epoch: 28 	Training Loss: 0.798911 	Validation Loss: 0.806657 	Validation Accuracy: 0.67 	time: 282.5
# Epoch: 29 	Training Loss: 0.797030 	Validation Loss: 0.807114 	Validation Accuracy: 0.67 	time: 279.8
# Epoch: 30 	Training Loss: 0.796162 	Validation Loss: 0.806430 	Validation Accuracy: 0.68 	time: 285.0
# Epoch: 31 	Training Loss: 0.798402 	Validation Loss: 0.808329 	Validation Accuracy: 0.67 	time: 286.2
# Epoch: 32 	Training Loss: 0.795274 	Validation Loss: 0.804325 	Validation Accuracy: 0.67 	time: 287.4
# Epoch: 33 	Training Loss: 0.801498 	Validation Loss: 0.801687 	Validation Accuracy: 0.68 	time: 290.1
# Epoch: 34 	Training Loss: 0.796772 	Validation Loss: 0.805318 	Validation Accuracy: 0.67 	time: 291.2
# Epoch: 35 	Training Loss: 0.798225 	Validation Loss: 0.812291 	Validation Accuracy: 0.67 	time: 293.2
# Epoch: 36 	Training Loss: 0.797170 	Validation Loss: 0.797400 	Validation Accuracy: 0.70 	time: 294.3
# Accuracy increased from 0.685000 to 0.700000. Model was saved
# Epoch: 37 	Training Loss: 0.799486 	Validation Loss: 0.809554 	Validation Accuracy: 0.67 	time: 292.4
# Epoch: 38 	Training Loss: 0.798257 	Validation Loss: 0.803152 	Validation Accuracy: 0.68 	time: 291.0
# Epoch: 39 	Training Loss: 0.796292 	Validation Loss: 0.798000 	Validation Accuracy: 0.69 	time: 289.3
# Epoch: 40 	Training Loss: 0.799474 	Validation Loss: 0.810469 	Validation Accuracy: 0.67 	time: 291.3
# Epoch: 41 	Training Loss: 0.799464 	Validation Loss: 0.805736 	Validation Accuracy: 0.68 	time: 293.4
# Epoch: 42 	Training Loss: 0.797434 	Validation Loss: 0.815595 	Validation Accuracy: 0.67 	time: 289.6
# Epoch: 43 	Training Loss: 0.796801 	Validation Loss: 0.809450 	Validation Accuracy: 0.68 	time: 286.4
# Epoch: 44 	Training Loss: 0.801322 	Validation Loss: 0.812406 	Validation Accuracy: 0.66 	time: 288.7
# Epoch: 45 	Training Loss: 0.797257 	Validation Loss: 0.808451 	Validation Accuracy: 0.66 	time: 291.4
# Epoch: 46 	Training Loss: 0.799290 	Validation Loss: 0.811143 	Validation Accuracy: 0.67 	time: 289.5
# Epoch: 47 	Training Loss: 0.796658 	Validation Loss: 0.823251 	Validation Accuracy: 0.65 	time: 290.9
# Epoch: 48 	Training Loss: 0.794546 	Validation Loss: 0.809644 	Validation Accuracy: 0.66 	time: 291.9
# Epoch: 49 	Training Loss: 0.794919 	Validation Loss: 0.815380 	Validation Accuracy: 0.65 	time: 290.8
# Epoch: 50 	Training Loss: 0.797907 	Validation Loss: 0.807458 	Validation Accuracy: 0.67 	time: 293.4
# Epoch: 51 	Training Loss: 0.798246 	Validation Loss: 0.810671 	Validation Accuracy: 0.68 	time: 291.1
# Epoch: 52 	Training Loss: 0.799517 	Validation Loss: 0.809646 	Validation Accuracy: 0.68 	time: 289.1
# Epoch: 53 	Training Loss: 0.799215 	Validation Loss: 0.800104 	Validation Accuracy: 0.69 	time: 284.2
# Epoch: 54 	Training Loss: 0.797672 	Validation Loss: 0.800089 	Validation Accuracy: 0.68 	time: 286.9
# Epoch: 55 	Training Loss: 0.797072 	Validation Loss: 0.806714 	Validation Accuracy: 0.67 	time: 290.4
# Epoch: 56 	Training Loss: 0.798840 	Validation Loss: 0.808002 	Validation Accuracy: 0.69 	time: 290.9
# Epoch: 57 	Training Loss: 0.799707 	Validation Loss: 0.815231 	Validation Accuracy: 0.67 	time: 295.9
# Epoch: 58 	Training Loss: 0.799083 	Validation Loss: 0.804642 	Validation Accuracy: 0.69 	time: 292.7
# Epoch: 59 	Training Loss: 0.796081 	Validation Loss: 0.807982 	Validation Accuracy: 0.66 	time: 296.8
# Epoch: 60 	Training Loss: 0.796551 	Validation Loss: 0.814252 	Validation Accuracy: 0.68 	time: 289.6
# Epoch: 61 	Training Loss: 0.799058 	Validation Loss: 0.807884 	Validation Accuracy: 0.68 	time: 297.5
# Epoch: 62 	Training Loss: 0.801632 	Validation Loss: 0.808741 	Validation Accuracy: 0.68 	time: 295.4
# Epoch: 63 	Training Loss: 0.798998 	Validation Loss: 0.803826 	Validation Accuracy: 0.70 	time: 294.4
# Epoch: 64 	Training Loss: 0.796974 	Validation Loss: 0.810858 	Validation Accuracy: 0.66 	time: 295.6
# Epoch: 65 	Training Loss: 0.797826 	Validation Loss: 0.806696 	Validation Accuracy: 0.68 	time: 291.7
# Epoch: 66 	Training Loss: 0.800252 	Validation Loss: 0.818831 	Validation Accuracy: 0.68 	time: 287.5
# Epoch: 67 	Training Loss: 0.797938 	Validation Loss: 0.813788 	Validation Accuracy: 0.66 	time: 286.8
# Epoch: 68 	Training Loss: 0.796074 	Validation Loss: 0.816573 	Validation Accuracy: 0.67 	time: 287.9
# Epoch: 69 	Training Loss: 0.799336 	Validation Loss: 0.811738 	Validation Accuracy: 0.67 	time: 286.6
# Epoch: 70 	Training Loss: 0.799240 	Validation Loss: 0.808782 	Validation Accuracy: 0.69 	time: 287.5
# Epoch: 71 	Training Loss: 0.797875 	Validation Loss: 0.808290 	Validation Accuracy: 0.67 	time: 290.5
# Epoch: 72 	Training Loss: 0.800471 	Validation Loss: 0.807380 	Validation Accuracy: 0.67 	time: 314.4
# early stop. return

# %%
# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer_v3221.pt'))

# %%
from PIL import Image
from torch.autograd import Variable

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = data_transfer['train'].classes

def predict_class_transfer(img_path):
    # load the image and return the predicted breed
    img = Image.open(img_path)

    transform = transforms.Compose([
                                transforms.Resize(224),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()
                               ]) 
    img = transform(img)
    img = img.unsqueeze(0) 

    img = Variable(img)

    img = img.to(device)
        
    prediction = model_transfer(img)  # Returns a Tensor of shape (batch, num class labels)
#     print(prediction)
#     print(class_names)
#     prediction = prediction.data.max(1, keepdim=True)[1]
    prediction = prediction.data.cpu().numpy().argmax()  # Our prediction will be the index of the class label with the largest value.
    prediction = class_names[prediction]
    return prediction 


# predict_class_transfer('../data/competition/02186.jpg')

# %%
#Get all test files

from glob import glob
import numpy as np

test_results = []

mango_files = np.array(glob("../data/competition/*"))

for idx, file in enumerate(mango_files):
    _ , filename = os.path.split(file)
    className = predict_class_transfer(file)
    test_results.append([filename, className])
    
# test_results[:3]

# %%
import csv

with open('results_v3221.csv', 'w') as f:

    writer = csv.writer(f)
    
    for row in test_results:
        writer.writerow(row)

# %%
def test(loaders, model, criterion):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_transfer, model_transfer, criterion_transfer)
# Out:
# Test Loss: 0.739381
#
#
# Test Accuracy: 65% (61/93)
